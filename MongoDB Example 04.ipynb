# %%
import requests
import pprint
from bs4 import BeautifulSoup

# %%
url = 'https://weather.com/weather/tenday/l/BRSP3446:1:BR'
page = requests.get(url)
soup = BeautifulSoup(page.text, 'html.parser')

# %%
data = []
table = soup.find('table', attrs = {'class': 'twc-table'})
print(table.prettify())
# Out:
# <table class="twc-table" classname="twc-table">
#  <thead>
#   <tr>
#    <th class=" twc-sticky-col" classname=" twc-sticky-col" id="day">
#     Day
#     <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#     </div>
#    </th>
#    <th class="description" classname="description" id="description">
#     Description
#    </th>
#    <th class="temp" classname="temp" id="hi-lo">
#     High / Low
#    </th>
#    <th class="precip" classname="precip" id="precip">
#     Precip
#    </th>
#    <th class="wind" classname="wind" id="wind">
#     Wind
#    </th>
#    <th class="humidity" classname="humidity" id="humidity">
#     Humidity
#    </th>
#   </tr>
#  </thead>
#  <tbody>
#   <tr class="clickable closed" classname="clickable closed">
#    <td class="twc-sticky-col cell-hide">
#     <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#     </div>
#    </td>
#    <td class="twc-sticky-col" classname="twc-sticky-col" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="day" title="Scattered thunderstorms. High 87F. Winds NW at 5 to 10 mph. Chance of rain 60%.">
#     <div>
#      <div>
#       <span class="date-time">
#        Today
#       </span>
#       <icon class="icon icon-svg icon-svg-dark icon-scattered-thunderstorms icon-38" classname="icon icon-svg icon-svg-dark icon-scattered-thunderstorms icon-38">
#        <svg class="svg-scattered-thunderstorms" viewbox="0 0 200 200" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <defs>
#          <mask id="scattered-thunderstorms-mask">
#           <rect fill="#FFF" height="100%" width="100%">
#           </rect>
#           <use stroke="#000" stroke-width="13" transform="matrix(1.8 0 0 1.8 -10.8 -25.2)" xlink:href="#svg-symbol-cloud">
#           </use>
#          </mask>
#         </defs>
#         <g transform="translate(0 -16)">
#          <use class="svg-sun" mask="url(#scattered-thunderstorms-mask)" transform="matrix(.56 0 0 .56 11.2 16.8)" xlink:href="#svg-symbol-sun">
#          </use>
#          <use class="svg-cloud" transform="matrix(.95 0 0 .95 7.6 5.7)" xlink:href="#svg-symbol-cloud">
#          </use>
#         </g>
#         <use class="svg-lightning" transform="matrix(.67 0 0 .67 30 61)" xlink:href="#svg-symbol-lightning-bolt">
#         </use>
#         <use class="svg-drop" transform="translate(57 21)" xlink:href="#svg-symbol-drop">
#         </use>
#         <use class="svg-drop" transform="translate(23 43)" xlink:href="#svg-symbol-drop">
#         </use>
#        </svg>
#       </icon>
#       <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#       </div>
#      </div>
#      <span class="day-detail clearfix">
#       FEB 23
#      </span>
#     </div>
#    </td>
#    <td class="description" classname="description" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="description" title="Scattered thunderstorms. High 87F. Winds NW at 5 to 10 mph. Chance of rain 60%.">
#     <span>
#      Scattered Thunderstorms
#     </span>
#    </td>
#    <td class="temp" classname="temp" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="hi-lo" title="Scattered thunderstorms. High 87F. Winds NW at 5 to 10 mph. Chance of rain 60%.">
#     <div>
#      <span class="">
#       87
#       <sup>
#        °
#       </sup>
#      </span>
#      <span class="slash" classname="slash">
#      </span>
#      <span class="">
#       69
#       <sup>
#        °
#       </sup>
#      </span>
#     </div>
#    </td>
#    <td class="precip" classname="precip" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="precip" title="Scattered thunderstorms. High 87F. Winds NW at 5 to 10 mph. Chance of rain 60%.">
#     <div>
#      <span class="icon icon-font iconset-weather-data icon-drop-1" classname="icon icon-font iconset-weather-data icon-drop-1">
#      </span>
#      <span class="">
#       <span>
#        60
#        <span class="Percentage__percentSymbol__2Q_AR">
#         %
#        </span>
#       </span>
#      </span>
#     </div>
#    </td>
#    <td class="wind" classname="wind" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="wind" title="Scattered thunderstorms. High 87F. Winds NW at 5 to 10 mph. Chance of rain 60%.">
#     <span class="">
#      NW 9 mph
#     </span>
#    </td>
#    <td class="humidity" classname="humidity" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="humidity" title="Scattered thunderstorms. High 87F. Winds NW at 5 to 10 mph. Chance of rain 60%.">
#     <span class="">
#      <span>
#       61
#       <span class="Percentage__percentSymbol__2Q_AR">
#        %
#       </span>
#      </span>
#     </span>
#    </td>
#   </tr>
#   <tr class="clickable closed" classname="clickable closed">
#    <td class="twc-sticky-col cell-hide">
#     <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#     </div>
#    </td>
#    <td class="twc-sticky-col" classname="twc-sticky-col" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="day" title="Scattered thunderstorms in the morning, then mainly cloudy during the afternoon with thunderstorms likely. High near 90F. Winds NNW at 10 to 15 mph. Chance of rain 80%.">
#     <div>
#      <div>
#       <span class="date-time">
#        Sun
#       </span>
#       <icon class="icon icon-svg icon-svg-dark icon-thunderstorm icon-4" classname="icon icon-svg icon-svg-dark icon-thunderstorm icon-4">
#        <svg class="svg-thunderstorm" viewbox="0 0 200 200" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use class="svg-cloud" transform="translate(0 -41)" xlink:href="#svg-symbol-cloud">
#         </use>
#         <use class="svg-lightning" xlink:href="#svg-symbol-lightning-bolt">
#         </use>
#         <use class="svg-drop" transform="translate(72)" xlink:href="#svg-symbol-drop">
#         </use>
#         <use class="svg-drop" transform="matrix(1.7 0 0 2 -16 -113)" xlink:href="#svg-symbol-drop">
#         </use>
#        </svg>
#       </icon>
#       <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#       </div>
#      </div>
#      <span class="day-detail clearfix">
#       FEB 24
#      </span>
#     </div>
#    </td>
#    <td class="description" classname="description" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="description" title="Scattered thunderstorms in the morning, then mainly cloudy during the afternoon with thunderstorms likely. High near 90F. Winds NNW at 10 to 15 mph. Chance of rain 80%.">
#     <span>
#      Thunderstorms
#     </span>
#    </td>
#    <td class="temp" classname="temp" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="hi-lo" title="Scattered thunderstorms in the morning, then mainly cloudy during the afternoon with thunderstorms likely. High near 90F. Winds NNW at 10 to 15 mph. Chance of rain 80%.">
#     <div>
#      <span class="">
#       90
#       <sup>
#        °
#       </sup>
#      </span>
#      <span class="slash" classname="slash">
#      </span>
#      <span class="">
#       70
#       <sup>
#        °
#       </sup>
#      </span>
#     </div>
#    </td>
#    <td class="precip" classname="precip" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="precip" title="Scattered thunderstorms in the morning, then mainly cloudy during the afternoon with thunderstorms likely. High near 90F. Winds NNW at 10 to 15 mph. Chance of rain 80%.">
#     <div>
#      <span class="icon icon-font iconset-weather-data icon-drop-1" classname="icon icon-font iconset-weather-data icon-drop-1">
#      </span>
#      <span class="">
#       <span>
#        80
#        <span class="Percentage__percentSymbol__2Q_AR">
#         %
#        </span>
#       </span>
#      </span>
#     </div>
#    </td>
#    <td class="wind" classname="wind" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="wind" title="Scattered thunderstorms in the morning, then mainly cloudy during the afternoon with thunderstorms likely. High near 90F. Winds NNW at 10 to 15 mph. Chance of rain 80%.">
#     <span class="">
#      NNW 10 mph
#     </span>
#    </td>
#    <td class="humidity" classname="humidity" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="humidity" title="Scattered thunderstorms in the morning, then mainly cloudy during the afternoon with thunderstorms likely. High near 90F. Winds NNW at 10 to 15 mph. Chance of rain 80%.">
#     <span class="">
#      <span>
#       61
#       <span class="Percentage__percentSymbol__2Q_AR">
#        %
#       </span>
#      </span>
#     </span>
#    </td>
#   </tr>
#   <tr class="clickable closed" classname="clickable closed">
#    <td class="twc-sticky-col cell-hide">
#     <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#     </div>
#    </td>
#    <td class="twc-sticky-col" classname="twc-sticky-col" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="day" title="Thunderstorms. High 86F. Winds NW at 10 to 15 mph. Chance of rain 80%.">
#     <div>
#      <div>
#       <span class="date-time">
#        Mon
#       </span>
#       <icon class="icon icon-svg icon-svg-dark icon-thunderstorm icon-4" classname="icon icon-svg icon-svg-dark icon-thunderstorm icon-4">
#        <svg class="svg-thunderstorm" viewbox="0 0 200 200" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use class="svg-cloud" transform="translate(0 -41)" xlink:href="#svg-symbol-cloud">
#         </use>
#         <use class="svg-lightning" xlink:href="#svg-symbol-lightning-bolt">
#         </use>
#         <use class="svg-drop" transform="translate(72)" xlink:href="#svg-symbol-drop">
#         </use>
#         <use class="svg-drop" transform="matrix(1.7 0 0 2 -16 -113)" xlink:href="#svg-symbol-drop">
#         </use>
#        </svg>
#       </icon>
#       <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#       </div>
#      </div>
#      <span class="day-detail clearfix">
#       FEB 25
#      </span>
#     </div>
#    </td>
#    <td class="description" classname="description" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="description" title="Thunderstorms. High 86F. Winds NW at 10 to 15 mph. Chance of rain 80%.">
#     <span>
#      Thunderstorms
#     </span>
#    </td>
#    <td class="temp" classname="temp" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="hi-lo" title="Thunderstorms. High 86F. Winds NW at 10 to 15 mph. Chance of rain 80%.">
#     <div>
#      <span class="">
#       86
#       <sup>
#        °
#       </sup>
#      </span>
#      <span class="slash" classname="slash">
#      </span>
#      <span class="">
#       69
#       <sup>
#        °
#       </sup>
#      </span>
#     </div>
#    </td>
#    <td class="precip" classname="precip" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="precip" title="Thunderstorms. High 86F. Winds NW at 10 to 15 mph. Chance of rain 80%.">
#     <div>
#      <span class="icon icon-font iconset-weather-data icon-drop-1" classname="icon icon-font iconset-weather-data icon-drop-1">
#      </span>
#      <span class="">
#       <span>
#        80
#        <span class="Percentage__percentSymbol__2Q_AR">
#         %
#        </span>
#       </span>
#      </span>
#     </div>
#    </td>
#    <td class="wind" classname="wind" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="wind" title="Thunderstorms. High 86F. Winds NW at 10 to 15 mph. Chance of rain 80%.">
#     <span class="">
#      NW 10 mph
#     </span>
#    </td>
#    <td class="humidity" classname="humidity" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="humidity" title="Thunderstorms. High 86F. Winds NW at 10 to 15 mph. Chance of rain 80%.">
#     <span class="">
#      <span>
#       67
#       <span class="Percentage__percentSymbol__2Q_AR">
#        %
#       </span>
#      </span>
#     </span>
#    </td>
#   </tr>
#   <tr class="clickable closed" classname="clickable closed">
#    <td class="twc-sticky-col cell-hide">
#     <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#     </div>
#    </td>
#    <td class="twc-sticky-col" classname="twc-sticky-col" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="day" title="Thunderstorms likely. High 82F. Winds NW at 5 to 10 mph. Chance of rain 100%.">
#     <div>
#      <div>
#       <span class="date-time">
#        Tue
#       </span>
#       <icon class="icon icon-svg icon-svg-dark icon-thunderstorm icon-4" classname="icon icon-svg icon-svg-dark icon-thunderstorm icon-4">
#        <svg class="svg-thunderstorm" viewbox="0 0 200 200" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use class="svg-cloud" transform="translate(0 -41)" xlink:href="#svg-symbol-cloud">
#         </use>
#         <use class="svg-lightning" xlink:href="#svg-symbol-lightning-bolt">
#         </use>
#         <use class="svg-drop" transform="translate(72)" xlink:href="#svg-symbol-drop">
#         </use>
#         <use class="svg-drop" transform="matrix(1.7 0 0 2 -16 -113)" xlink:href="#svg-symbol-drop">
#         </use>
#        </svg>
#       </icon>
#       <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#       </div>
#      </div>
#      <span class="day-detail clearfix">
#       FEB 26
#      </span>
#     </div>
#    </td>
#    <td class="description" classname="description" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="description" title="Thunderstorms likely. High 82F. Winds NW at 5 to 10 mph. Chance of rain 100%.">
#     <span>
#      Thunderstorms
#     </span>
#    </td>
#    <td class="temp" classname="temp" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="hi-lo" title="Thunderstorms likely. High 82F. Winds NW at 5 to 10 mph. Chance of rain 100%.">
#     <div>
#      <span class="">
#       82
#       <sup>
#        °
#       </sup>
#      </span>
#      <span class="slash" classname="slash">
#      </span>
#      <span class="">
#       69
#       <sup>
#        °
#       </sup>
#      </span>
#     </div>
#    </td>
#    <td class="precip" classname="precip" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="precip" title="Thunderstorms likely. High 82F. Winds NW at 5 to 10 mph. Chance of rain 100%.">
#     <div>
#      <span class="icon icon-font iconset-weather-data icon-drop-1" classname="icon icon-font iconset-weather-data icon-drop-1">
#      </span>
#      <span class="">
#       <span>
#        100
#        <span class="Percentage__percentSymbol__2Q_AR">
#         %
#        </span>
#       </span>
#      </span>
#     </div>
#    </td>
#    <td class="wind" classname="wind" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="wind" title="Thunderstorms likely. High 82F. Winds NW at 5 to 10 mph. Chance of rain 100%.">
#     <span class="">
#      NW 8 mph
#     </span>
#    </td>
#    <td class="humidity" classname="humidity" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="humidity" title="Thunderstorms likely. High 82F. Winds NW at 5 to 10 mph. Chance of rain 100%.">
#     <span class="">
#      <span>
#       75
#       <span class="Percentage__percentSymbol__2Q_AR">
#        %
#       </span>
#      </span>
#     </span>
#    </td>
#   </tr>
#   <tr class="clickable closed" classname="clickable closed">
#    <td class="twc-sticky-col cell-hide">
#     <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#     </div>
#    </td>
#    <td class="twc-sticky-col" classname="twc-sticky-col" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="day" title="Thunderstorms likely. High 79F. Winds NW at 5 to 10 mph. Chance of rain 90%.">
#     <div>
#      <div>
#       <span class="date-time">
#        Wed
#       </span>
#       <icon class="icon icon-svg icon-svg-dark icon-thunderstorm icon-4" classname="icon icon-svg icon-svg-dark icon-thunderstorm icon-4">
#        <svg class="svg-thunderstorm" viewbox="0 0 200 200" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use class="svg-cloud" transform="translate(0 -41)" xlink:href="#svg-symbol-cloud">
#         </use>
#         <use class="svg-lightning" xlink:href="#svg-symbol-lightning-bolt">
#         </use>
#         <use class="svg-drop" transform="translate(72)" xlink:href="#svg-symbol-drop">
#         </use>
#         <use class="svg-drop" transform="matrix(1.7 0 0 2 -16 -113)" xlink:href="#svg-symbol-drop">
#         </use>
#        </svg>
#       </icon>
#       <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#       </div>
#      </div>
#      <span class="day-detail clearfix">
#       FEB 27
#      </span>
#     </div>
#    </td>
#    <td class="description" classname="description" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="description" title="Thunderstorms likely. High 79F. Winds NW at 5 to 10 mph. Chance of rain 90%.">
#     <span>
#      Thunderstorms
#     </span>
#    </td>
#    <td class="temp" classname="temp" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="hi-lo" title="Thunderstorms likely. High 79F. Winds NW at 5 to 10 mph. Chance of rain 90%.">
#     <div>
#      <span class="">
#       79
#       <sup>
#        °
#       </sup>
#      </span>
#      <span class="slash" classname="slash">
#      </span>
#      <span class="">
#       68
#       <sup>
#        °
#       </sup>
#      </span>
#     </div>
#    </td>
#    <td class="precip" classname="precip" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="precip" title="Thunderstorms likely. High 79F. Winds NW at 5 to 10 mph. Chance of rain 90%.">
#     <div>
#      <span class="icon icon-font iconset-weather-data icon-drop-1" classname="icon icon-font iconset-weather-data icon-drop-1">
#      </span>
#      <span class="">
#       <span>
#        90
#        <span class="Percentage__percentSymbol__2Q_AR">
#         %
#        </span>
#       </span>
#      </span>
#     </div>
#    </td>
#    <td class="wind" classname="wind" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="wind" title="Thunderstorms likely. High 79F. Winds NW at 5 to 10 mph. Chance of rain 90%.">
#     <span class="">
#      NW 7 mph
#     </span>
#    </td>
#    <td class="humidity" classname="humidity" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="humidity" title="Thunderstorms likely. High 79F. Winds NW at 5 to 10 mph. Chance of rain 90%.">
#     <span class="">
#      <span>
#       79
#       <span class="Percentage__percentSymbol__2Q_AR">
#        %
#       </span>
#      </span>
#     </span>
#    </td>
#   </tr>
#   <tr class="clickable closed" classname="clickable closed">
#    <td class="twc-sticky-col cell-hide">
#     <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#     </div>
#    </td>
#    <td class="twc-sticky-col" classname="twc-sticky-col" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="day" title="Thunderstorms likely. High 78F. Winds N at 5 to 10 mph. Chance of rain 90%.">
#     <div>
#      <div>
#       <span class="date-time">
#        Thu
#       </span>
#       <icon class="icon icon-svg icon-svg-dark icon-thunderstorm icon-4" classname="icon icon-svg icon-svg-dark icon-thunderstorm icon-4">
#        <svg class="svg-thunderstorm" viewbox="0 0 200 200" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use class="svg-cloud" transform="translate(0 -41)" xlink:href="#svg-symbol-cloud">
#         </use>
#         <use class="svg-lightning" xlink:href="#svg-symbol-lightning-bolt">
#         </use>
#         <use class="svg-drop" transform="translate(72)" xlink:href="#svg-symbol-drop">
#         </use>
#         <use class="svg-drop" transform="matrix(1.7 0 0 2 -16 -113)" xlink:href="#svg-symbol-drop">
#         </use>
#        </svg>
#       </icon>
#       <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#       </div>
#      </div>
#      <span class="day-detail clearfix">
#       FEB 28
#      </span>
#     </div>
#    </td>
#    <td class="description" classname="description" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="description" title="Thunderstorms likely. High 78F. Winds N at 5 to 10 mph. Chance of rain 90%.">
#     <span>
#      Thunderstorms
#     </span>
#    </td>
#    <td class="temp" classname="temp" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="hi-lo" title="Thunderstorms likely. High 78F. Winds N at 5 to 10 mph. Chance of rain 90%.">
#     <div>
#      <span class="">
#       78
#       <sup>
#        °
#       </sup>
#      </span>
#      <span class="slash" classname="slash">
#      </span>
#      <span class="">
#       67
#       <sup>
#        °
#       </sup>
#      </span>
#     </div>
#    </td>
#    <td class="precip" classname="precip" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="precip" title="Thunderstorms likely. High 78F. Winds N at 5 to 10 mph. Chance of rain 90%.">
#     <div>
#      <span class="icon icon-font iconset-weather-data icon-drop-1" classname="icon icon-font iconset-weather-data icon-drop-1">
#      </span>
#      <span class="">
#       <span>
#        90
#        <span class="Percentage__percentSymbol__2Q_AR">
#         %
#        </span>
#       </span>
#      </span>
#     </div>
#    </td>
#    <td class="wind" classname="wind" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="wind" title="Thunderstorms likely. High 78F. Winds N at 5 to 10 mph. Chance of rain 90%.">
#     <span class="">
#      N 6 mph
#     </span>
#    </td>
#    <td class="humidity" classname="humidity" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="humidity" title="Thunderstorms likely. High 78F. Winds N at 5 to 10 mph. Chance of rain 90%.">
#     <span class="">
#      <span>
#       82
#       <span class="Percentage__percentSymbol__2Q_AR">
#        %
#       </span>
#      </span>
#     </span>
#    </td>
#   </tr>
#   <tr class="clickable closed" classname="clickable closed">
#    <td class="twc-sticky-col cell-hide">
#     <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#     </div>
#    </td>
#    <td class="twc-sticky-col" classname="twc-sticky-col" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="day" title="Thunderstorms likely. High 79F. Winds E at 5 to 10 mph. Chance of rain 80%.">
#     <div>
#      <div>
#       <span class="date-time">
#        Fri
#       </span>
#       <icon class="icon icon-svg icon-svg-dark icon-thunderstorm icon-4" classname="icon icon-svg icon-svg-dark icon-thunderstorm icon-4">
#        <svg class="svg-thunderstorm" viewbox="0 0 200 200" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use class="svg-cloud" transform="translate(0 -41)" xlink:href="#svg-symbol-cloud">
#         </use>
#         <use class="svg-lightning" xlink:href="#svg-symbol-lightning-bolt">
#         </use>
#         <use class="svg-drop" transform="translate(72)" xlink:href="#svg-symbol-drop">
#         </use>
#         <use class="svg-drop" transform="matrix(1.7 0 0 2 -16 -113)" xlink:href="#svg-symbol-drop">
#         </use>
#        </svg>
#       </icon>
#       <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#       </div>
#      </div>
#      <span class="day-detail clearfix">
#       MAR 1
#      </span>
#     </div>
#    </td>
#    <td class="description" classname="description" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="description" title="Thunderstorms likely. High 79F. Winds E at 5 to 10 mph. Chance of rain 80%.">
#     <span>
#      Thunderstorms
#     </span>
#    </td>
#    <td class="temp" classname="temp" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="hi-lo" title="Thunderstorms likely. High 79F. Winds E at 5 to 10 mph. Chance of rain 80%.">
#     <div>
#      <span class="">
#       79
#       <sup>
#        °
#       </sup>
#      </span>
#      <span class="slash" classname="slash">
#      </span>
#      <span class="">
#       67
#       <sup>
#        °
#       </sup>
#      </span>
#     </div>
#    </td>
#    <td class="precip" classname="precip" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="precip" title="Thunderstorms likely. High 79F. Winds E at 5 to 10 mph. Chance of rain 80%.">
#     <div>
#      <span class="icon icon-font iconset-weather-data icon-drop-1" classname="icon icon-font iconset-weather-data icon-drop-1">
#      </span>
#      <span class="">
#       <span>
#        80
#        <span class="Percentage__percentSymbol__2Q_AR">
#         %
#        </span>
#       </span>
#      </span>
#     </div>
#    </td>
#    <td class="wind" classname="wind" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="wind" title="Thunderstorms likely. High 79F. Winds E at 5 to 10 mph. Chance of rain 80%.">
#     <span class="">
#      E 6 mph
#     </span>
#    </td>
#    <td class="humidity" classname="humidity" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="humidity" title="Thunderstorms likely. High 79F. Winds E at 5 to 10 mph. Chance of rain 80%.">
#     <span class="">
#      <span>
#       80
#       <span class="Percentage__percentSymbol__2Q_AR">
#        %
#       </span>
#      </span>
#     </span>
#    </td>
#   </tr>
#   <tr class="clickable closed" classname="clickable closed">
#    <td class="twc-sticky-col cell-hide">
#     <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#     </div>
#    </td>
#    <td class="twc-sticky-col" classname="twc-sticky-col" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="day" title="Thunderstorms likely. High 79F. Winds ENE at 5 to 10 mph. Chance of rain 80%.">
#     <div>
#      <div>
#       <span class="date-time">
#        Sat
#       </span>
#       <icon class="icon icon-svg icon-svg-dark icon-thunderstorm icon-4" classname="icon icon-svg icon-svg-dark icon-thunderstorm icon-4">
#        <svg class="svg-thunderstorm" viewbox="0 0 200 200" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use class="svg-cloud" transform="translate(0 -41)" xlink:href="#svg-symbol-cloud">
#         </use>
#         <use class="svg-lightning" xlink:href="#svg-symbol-lightning-bolt">
#         </use>
#         <use class="svg-drop" transform="translate(72)" xlink:href="#svg-symbol-drop">
#         </use>
#         <use class="svg-drop" transform="matrix(1.7 0 0 2 -16 -113)" xlink:href="#svg-symbol-drop">
#         </use>
#        </svg>
#       </icon>
#       <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#       </div>
#      </div>
#      <span class="day-detail clearfix">
#       MAR 2
#      </span>
#     </div>
#    </td>
#    <td class="description" classname="description" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="description" title="Thunderstorms likely. High 79F. Winds ENE at 5 to 10 mph. Chance of rain 80%.">
#     <span>
#      Thunderstorms
#     </span>
#    </td>
#    <td class="temp" classname="temp" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="hi-lo" title="Thunderstorms likely. High 79F. Winds ENE at 5 to 10 mph. Chance of rain 80%.">
#     <div>
#      <span class="">
#       79
#       <sup>
#        °
#       </sup>
#      </span>
#      <span class="slash" classname="slash">
#      </span>
#      <span class="">
#       67
#       <sup>
#        °
#       </sup>
#      </span>
#     </div>
#    </td>
#    <td class="precip" classname="precip" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="precip" title="Thunderstorms likely. High 79F. Winds ENE at 5 to 10 mph. Chance of rain 80%.">
#     <div>
#      <span class="icon icon-font iconset-weather-data icon-drop-1" classname="icon icon-font iconset-weather-data icon-drop-1">
#      </span>
#      <span class="">
#       <span>
#        80
#        <span class="Percentage__percentSymbol__2Q_AR">
#         %
#        </span>
#       </span>
#      </span>
#     </div>
#    </td>
#    <td class="wind" classname="wind" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="wind" title="Thunderstorms likely. High 79F. Winds ENE at 5 to 10 mph. Chance of rain 80%.">
#     <span class="">
#      ENE 6 mph
#     </span>
#    </td>
#    <td class="humidity" classname="humidity" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="humidity" title="Thunderstorms likely. High 79F. Winds ENE at 5 to 10 mph. Chance of rain 80%.">
#     <span class="">
#      <span>
#       79
#       <span class="Percentage__percentSymbol__2Q_AR">
#        %
#       </span>
#      </span>
#     </span>
#    </td>
#   </tr>
#   <tr class="clickable closed" classname="clickable closed">
#    <td class="twc-sticky-col cell-hide">
#     <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#     </div>
#    </td>
#    <td class="twc-sticky-col" classname="twc-sticky-col" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="day" title="Thunderstorms likely. High 81F. Winds ENE at 5 to 10 mph. Chance of rain 80%.">
#     <div>
#      <div>
#       <span class="date-time">
#        Sun
#       </span>
#       <icon class="icon icon-svg icon-svg-dark icon-thunderstorm icon-4" classname="icon icon-svg icon-svg-dark icon-thunderstorm icon-4">
#        <svg class="svg-thunderstorm" viewbox="0 0 200 200" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use class="svg-cloud" transform="translate(0 -41)" xlink:href="#svg-symbol-cloud">
#         </use>
#         <use class="svg-lightning" xlink:href="#svg-symbol-lightning-bolt">
#         </use>
#         <use class="svg-drop" transform="translate(72)" xlink:href="#svg-symbol-drop">
#         </use>
#         <use class="svg-drop" transform="matrix(1.7 0 0 2 -16 -113)" xlink:href="#svg-symbol-drop">
#         </use>
#        </svg>
#       </icon>
#       <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#       </div>
#      </div>
#      <span class="day-detail clearfix">
#       MAR 3
#      </span>
#     </div>
#    </td>
#    <td class="description" classname="description" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="description" title="Thunderstorms likely. High 81F. Winds ENE at 5 to 10 mph. Chance of rain 80%.">
#     <span>
#      Thunderstorms
#     </span>
#    </td>
#    <td class="temp" classname="temp" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="hi-lo" title="Thunderstorms likely. High 81F. Winds ENE at 5 to 10 mph. Chance of rain 80%.">
#     <div>
#      <span class="">
#       81
#       <sup>
#        °
#       </sup>
#      </span>
#      <span class="slash" classname="slash">
#      </span>
#      <span class="">
#       67
#       <sup>
#        °
#       </sup>
#      </span>
#     </div>
#    </td>
#    <td class="precip" classname="precip" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="precip" title="Thunderstorms likely. High 81F. Winds ENE at 5 to 10 mph. Chance of rain 80%.">
#     <div>
#      <span class="icon icon-font iconset-weather-data icon-drop-1" classname="icon icon-font iconset-weather-data icon-drop-1">
#      </span>
#      <span class="">
#       <span>
#        80
#        <span class="Percentage__percentSymbol__2Q_AR">
#         %
#        </span>
#       </span>
#      </span>
#     </div>
#    </td>
#    <td class="wind" classname="wind" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="wind" title="Thunderstorms likely. High 81F. Winds ENE at 5 to 10 mph. Chance of rain 80%.">
#     <span class="">
#      ENE 6 mph
#     </span>
#    </td>
#    <td class="humidity" classname="humidity" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="humidity" title="Thunderstorms likely. High 81F. Winds ENE at 5 to 10 mph. Chance of rain 80%.">
#     <span class="">
#      <span>
#       76
#       <span class="Percentage__percentSymbol__2Q_AR">
#        %
#       </span>
#      </span>
#     </span>
#    </td>
#   </tr>
#   <tr class="clickable closed" classname="clickable closed">
#    <td class="twc-sticky-col cell-hide">
#     <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#     </div>
#    </td>
#    <td class="twc-sticky-col" classname="twc-sticky-col" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="day" title="Thunderstorms likely. High 81F. Winds ENE at 5 to 10 mph. Chance of rain 80%.">
#     <div>
#      <div>
#       <span class="date-time">
#        Mon
#       </span>
#       <icon class="icon icon-svg icon-svg-dark icon-thunderstorm icon-4" classname="icon icon-svg icon-svg-dark icon-thunderstorm icon-4">
#        <svg class="svg-thunderstorm" viewbox="0 0 200 200" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use class="svg-cloud" transform="translate(0 -41)" xlink:href="#svg-symbol-cloud">
#         </use>
#         <use class="svg-lightning" xlink:href="#svg-symbol-lightning-bolt">
#         </use>
#         <use class="svg-drop" transform="translate(72)" xlink:href="#svg-symbol-drop">
#         </use>
#         <use class="svg-drop" transform="matrix(1.7 0 0 2 -16 -113)" xlink:href="#svg-symbol-drop">
#         </use>
#        </svg>
#       </icon>
#       <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#       </div>
#      </div>
#      <span class="day-detail clearfix">
#       MAR 4
#      </span>
#     </div>
#    </td>
#    <td class="description" classname="description" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="description" title="Thunderstorms likely. High 81F. Winds ENE at 5 to 10 mph. Chance of rain 80%.">
#     <span>
#      Thunderstorms
#     </span>
#    </td>
#    <td class="temp" classname="temp" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="hi-lo" title="Thunderstorms likely. High 81F. Winds ENE at 5 to 10 mph. Chance of rain 80%.">
#     <div>
#      <span class="">
#       81
#       <sup>
#        °
#       </sup>
#      </span>
#      <span class="slash" classname="slash">
#      </span>
#      <span class="">
#       67
#       <sup>
#        °
#       </sup>
#      </span>
#     </div>
#    </td>
#    <td class="precip" classname="precip" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="precip" title="Thunderstorms likely. High 81F. Winds ENE at 5 to 10 mph. Chance of rain 80%.">
#     <div>
#      <span class="icon icon-font iconset-weather-data icon-drop-1" classname="icon icon-font iconset-weather-data icon-drop-1">
#      </span>
#      <span class="">
#       <span>
#        80
#        <span class="Percentage__percentSymbol__2Q_AR">
#         %
#        </span>
#       </span>
#      </span>
#     </div>
#    </td>
#    <td class="wind" classname="wind" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="wind" title="Thunderstorms likely. High 81F. Winds ENE at 5 to 10 mph. Chance of rain 80%.">
#     <span class="">
#      ENE 6 mph
#     </span>
#    </td>
#    <td class="humidity" classname="humidity" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="humidity" title="Thunderstorms likely. High 81F. Winds ENE at 5 to 10 mph. Chance of rain 80%.">
#     <span class="">
#      <span>
#       74
#       <span class="Percentage__percentSymbol__2Q_AR">
#        %
#       </span>
#      </span>
#     </span>
#    </td>
#   </tr>
#   <tr class="clickable closed" classname="clickable closed">
#    <td class="twc-sticky-col cell-hide">
#     <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#     </div>
#    </td>
#    <td class="twc-sticky-col" classname="twc-sticky-col" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="day" title="Thunderstorms. High 83F. Winds NNE at 5 to 10 mph. Chance of rain 80%.">
#     <div>
#      <div>
#       <span class="date-time">
#        Tue
#       </span>
#       <icon class="icon icon-svg icon-svg-dark icon-thunderstorm icon-4" classname="icon icon-svg icon-svg-dark icon-thunderstorm icon-4">
#        <svg class="svg-thunderstorm" viewbox="0 0 200 200" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use class="svg-cloud" transform="translate(0 -41)" xlink:href="#svg-symbol-cloud">
#         </use>
#         <use class="svg-lightning" xlink:href="#svg-symbol-lightning-bolt">
#         </use>
#         <use class="svg-drop" transform="translate(72)" xlink:href="#svg-symbol-drop">
#         </use>
#         <use class="svg-drop" transform="matrix(1.7 0 0 2 -16 -113)" xlink:href="#svg-symbol-drop">
#         </use>
#        </svg>
#       </icon>
#       <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#       </div>
#      </div>
#      <span class="day-detail clearfix">
#       MAR 5
#      </span>
#     </div>
#    </td>
#    <td class="description" classname="description" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="description" title="Thunderstorms. High 83F. Winds NNE at 5 to 10 mph. Chance of rain 80%.">
#     <span>
#      Thunderstorms
#     </span>
#    </td>
#    <td class="temp" classname="temp" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="hi-lo" title="Thunderstorms. High 83F. Winds NNE at 5 to 10 mph. Chance of rain 80%.">
#     <div>
#      <span class="">
#       83
#       <sup>
#        °
#       </sup>
#      </span>
#      <span class="slash" classname="slash">
#      </span>
#      <span class="">
#       68
#       <sup>
#        °
#       </sup>
#      </span>
#     </div>
#    </td>
#    <td class="precip" classname="precip" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="precip" title="Thunderstorms. High 83F. Winds NNE at 5 to 10 mph. Chance of rain 80%.">
#     <div>
#      <span class="icon icon-font iconset-weather-data icon-drop-1" classname="icon icon-font iconset-weather-data icon-drop-1">
#      </span>
#      <span class="">
#       <span>
#        80
#        <span class="Percentage__percentSymbol__2Q_AR">
#         %
#        </span>
#       </span>
#      </span>
#     </div>
#    </td>
#    <td class="wind" classname="wind" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="wind" title="Thunderstorms. High 83F. Winds NNE at 5 to 10 mph. Chance of rain 80%.">
#     <span class="">
#      NNE 7 mph
#     </span>
#    </td>
#    <td class="humidity" classname="humidity" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="humidity" title="Thunderstorms. High 83F. Winds NNE at 5 to 10 mph. Chance of rain 80%.">
#     <span class="">
#      <span>
#       72
#       <span class="Percentage__percentSymbol__2Q_AR">
#        %
#       </span>
#      </span>
#     </span>
#    </td>
#   </tr>
#   <tr class="clickable closed" classname="clickable closed">
#    <td class="twc-sticky-col cell-hide">
#     <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#     </div>
#    </td>
#    <td class="twc-sticky-col" classname="twc-sticky-col" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="day" title="Scattered thunderstorms in the morning, then mainly cloudy during the afternoon with thunderstorms likely. High 83F. Winds N at 5 to 10 mph. Chance of rain 80%.">
#     <div>
#      <div>
#       <span class="date-time">
#        Wed
#       </span>
#       <icon class="icon icon-svg icon-svg-dark icon-thunderstorm icon-4" classname="icon icon-svg icon-svg-dark icon-thunderstorm icon-4">
#        <svg class="svg-thunderstorm" viewbox="0 0 200 200" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use class="svg-cloud" transform="translate(0 -41)" xlink:href="#svg-symbol-cloud">
#         </use>
#         <use class="svg-lightning" xlink:href="#svg-symbol-lightning-bolt">
#         </use>
#         <use class="svg-drop" transform="translate(72)" xlink:href="#svg-symbol-drop">
#         </use>
#         <use class="svg-drop" transform="matrix(1.7 0 0 2 -16 -113)" xlink:href="#svg-symbol-drop">
#         </use>
#        </svg>
#       </icon>
#       <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#       </div>
#      </div>
#      <span class="day-detail clearfix">
#       MAR 6
#      </span>
#     </div>
#    </td>
#    <td class="description" classname="description" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="description" title="Scattered thunderstorms in the morning, then mainly cloudy during the afternoon with thunderstorms likely. High 83F. Winds N at 5 to 10 mph. Chance of rain 80%.">
#     <span>
#      Thunderstorms
#     </span>
#    </td>
#    <td class="temp" classname="temp" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="hi-lo" title="Scattered thunderstorms in the morning, then mainly cloudy during the afternoon with thunderstorms likely. High 83F. Winds N at 5 to 10 mph. Chance of rain 80%.">
#     <div>
#      <span class="">
#       83
#       <sup>
#        °
#       </sup>
#      </span>
#      <span class="slash" classname="slash">
#      </span>
#      <span class="">
#       68
#       <sup>
#        °
#       </sup>
#      </span>
#     </div>
#    </td>
#    <td class="precip" classname="precip" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="precip" title="Scattered thunderstorms in the morning, then mainly cloudy during the afternoon with thunderstorms likely. High 83F. Winds N at 5 to 10 mph. Chance of rain 80%.">
#     <div>
#      <span class="icon icon-font iconset-weather-data icon-drop-1" classname="icon icon-font iconset-weather-data icon-drop-1">
#      </span>
#      <span class="">
#       <span>
#        80
#        <span class="Percentage__percentSymbol__2Q_AR">
#         %
#        </span>
#       </span>
#      </span>
#     </div>
#    </td>
#    <td class="wind" classname="wind" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="wind" title="Scattered thunderstorms in the morning, then mainly cloudy during the afternoon with thunderstorms likely. High 83F. Winds N at 5 to 10 mph. Chance of rain 80%.">
#     <span class="">
#      N 6 mph
#     </span>
#    </td>
#    <td class="humidity" classname="humidity" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="humidity" title="Scattered thunderstorms in the morning, then mainly cloudy during the afternoon with thunderstorms likely. High 83F. Winds N at 5 to 10 mph. Chance of rain 80%.">
#     <span class="">
#      <span>
#       70
#       <span class="Percentage__percentSymbol__2Q_AR">
#        %
#       </span>
#      </span>
#     </span>
#    </td>
#   </tr>
#   <tr class="clickable closed" classname="clickable closed">
#    <td class="twc-sticky-col cell-hide">
#     <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#     </div>
#    </td>
#    <td class="twc-sticky-col" classname="twc-sticky-col" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="day" title="Scattered thunderstorms. High 84F. Winds NNE at 5 to 10 mph. Chance of rain 60%.">
#     <div>
#      <div>
#       <span class="date-time">
#        Thu
#       </span>
#       <icon class="icon icon-svg icon-svg-dark icon-scattered-thunderstorms icon-38" classname="icon icon-svg icon-svg-dark icon-scattered-thunderstorms icon-38">
#        <svg class="svg-scattered-thunderstorms" viewbox="0 0 200 200" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <defs>
#          <mask id="scattered-thunderstorms-mask">
#           <rect fill="#FFF" height="100%" width="100%">
#           </rect>
#           <use stroke="#000" stroke-width="13" transform="matrix(1.8 0 0 1.8 -10.8 -25.2)" xlink:href="#svg-symbol-cloud">
#           </use>
#          </mask>
#         </defs>
#         <g transform="translate(0 -16)">
#          <use class="svg-sun" mask="url(#scattered-thunderstorms-mask)" transform="matrix(.56 0 0 .56 11.2 16.8)" xlink:href="#svg-symbol-sun">
#          </use>
#          <use class="svg-cloud" transform="matrix(.95 0 0 .95 7.6 5.7)" xlink:href="#svg-symbol-cloud">
#          </use>
#         </g>
#         <use class="svg-lightning" transform="matrix(.67 0 0 .67 30 61)" xlink:href="#svg-symbol-lightning-bolt">
#         </use>
#         <use class="svg-drop" transform="translate(57 21)" xlink:href="#svg-symbol-drop">
#         </use>
#         <use class="svg-drop" transform="translate(23 43)" xlink:href="#svg-symbol-drop">
#         </use>
#        </svg>
#       </icon>
#       <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#       </div>
#      </div>
#      <span class="day-detail clearfix">
#       MAR 7
#      </span>
#     </div>
#    </td>
#    <td class="description" classname="description" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="description" title="Scattered thunderstorms. High 84F. Winds NNE at 5 to 10 mph. Chance of rain 60%.">
#     <span>
#      Scattered Thunderstorms
#     </span>
#    </td>
#    <td class="temp" classname="temp" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="hi-lo" title="Scattered thunderstorms. High 84F. Winds NNE at 5 to 10 mph. Chance of rain 60%.">
#     <div>
#      <span class="">
#       84
#       <sup>
#        °
#       </sup>
#      </span>
#      <span class="slash" classname="slash">
#      </span>
#      <span class="">
#       68
#       <sup>
#        °
#       </sup>
#      </span>
#     </div>
#    </td>
#    <td class="precip" classname="precip" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="precip" title="Scattered thunderstorms. High 84F. Winds NNE at 5 to 10 mph. Chance of rain 60%.">
#     <div>
#      <span class="icon icon-font iconset-weather-data icon-drop-1" classname="icon icon-font iconset-weather-data icon-drop-1">
#      </span>
#      <span class="">
#       <span>
#        60
#        <span class="Percentage__percentSymbol__2Q_AR">
#         %
#        </span>
#       </span>
#      </span>
#     </div>
#    </td>
#    <td class="wind" classname="wind" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="wind" title="Scattered thunderstorms. High 84F. Winds NNE at 5 to 10 mph. Chance of rain 60%.">
#     <span class="">
#      NNE 6 mph
#     </span>
#    </td>
#    <td class="humidity" classname="humidity" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="humidity" title="Scattered thunderstorms. High 84F. Winds NNE at 5 to 10 mph. Chance of rain 60%.">
#     <span class="">
#      <span>
#       69
#       <span class="Percentage__percentSymbol__2Q_AR">
#        %
#       </span>
#      </span>
#     </span>
#    </td>
#   </tr>
#   <tr class="clickable closed" classname="clickable closed">
#    <td class="twc-sticky-col cell-hide">
#     <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#     </div>
#    </td>
#    <td class="twc-sticky-col" classname="twc-sticky-col" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="day" title="Mixed clouds and sun with scattered thunderstorms. High 84F. Winds NE at 5 to 10 mph. Chance of rain 60%.">
#     <div>
#      <div>
#       <span class="date-time">
#        Fri
#       </span>
#       <icon class="icon icon-svg icon-svg-dark icon-scattered-thunderstorms icon-38" classname="icon icon-svg icon-svg-dark icon-scattered-thunderstorms icon-38">
#        <svg class="svg-scattered-thunderstorms" viewbox="0 0 200 200" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <defs>
#          <mask id="scattered-thunderstorms-mask">
#           <rect fill="#FFF" height="100%" width="100%">
#           </rect>
#           <use stroke="#000" stroke-width="13" transform="matrix(1.8 0 0 1.8 -10.8 -25.2)" xlink:href="#svg-symbol-cloud">
#           </use>
#          </mask>
#         </defs>
#         <g transform="translate(0 -16)">
#          <use class="svg-sun" mask="url(#scattered-thunderstorms-mask)" transform="matrix(.56 0 0 .56 11.2 16.8)" xlink:href="#svg-symbol-sun">
#          </use>
#          <use class="svg-cloud" transform="matrix(.95 0 0 .95 7.6 5.7)" xlink:href="#svg-symbol-cloud">
#          </use>
#         </g>
#         <use class="svg-lightning" transform="matrix(.67 0 0 .67 30 61)" xlink:href="#svg-symbol-lightning-bolt">
#         </use>
#         <use class="svg-drop" transform="translate(57 21)" xlink:href="#svg-symbol-drop">
#         </use>
#         <use class="svg-drop" transform="translate(23 43)" xlink:href="#svg-symbol-drop">
#         </use>
#        </svg>
#       </icon>
#       <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#       </div>
#      </div>
#      <span class="day-detail clearfix">
#       MAR 8
#      </span>
#     </div>
#    </td>
#    <td class="description" classname="description" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="description" title="Mixed clouds and sun with scattered thunderstorms. High 84F. Winds NE at 5 to 10 mph. Chance of rain 60%.">
#     <span>
#      Scattered Thunderstorms
#     </span>
#    </td>
#    <td class="temp" classname="temp" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="hi-lo" title="Mixed clouds and sun with scattered thunderstorms. High 84F. Winds NE at 5 to 10 mph. Chance of rain 60%.">
#     <div>
#      <span class="">
#       84
#       <sup>
#        °
#       </sup>
#      </span>
#      <span class="slash" classname="slash">
#      </span>
#      <span class="">
#       68
#       <sup>
#        °
#       </sup>
#      </span>
#     </div>
#    </td>
#    <td class="precip" classname="precip" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="precip" title="Mixed clouds and sun with scattered thunderstorms. High 84F. Winds NE at 5 to 10 mph. Chance of rain 60%.">
#     <div>
#      <span class="icon icon-font iconset-weather-data icon-drop-1" classname="icon icon-font iconset-weather-data icon-drop-1">
#      </span>
#      <span class="">
#       <span>
#        60
#        <span class="Percentage__percentSymbol__2Q_AR">
#         %
#        </span>
#       </span>
#      </span>
#     </div>
#    </td>
#    <td class="wind" classname="wind" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="wind" title="Mixed clouds and sun with scattered thunderstorms. High 84F. Winds NE at 5 to 10 mph. Chance of rain 60%.">
#     <span class="">
#      NE 6 mph
#     </span>
#    </td>
#    <td class="humidity" classname="humidity" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="humidity" title="Mixed clouds and sun with scattered thunderstorms. High 84F. Winds NE at 5 to 10 mph. Chance of rain 60%.">
#     <span class="">
#      <span>
#       69
#       <span class="Percentage__percentSymbol__2Q_AR">
#        %
#       </span>
#      </span>
#     </span>
#    </td>
#   </tr>
#   <tr class="clickable closed" classname="clickable closed">
#    <td class="twc-sticky-col cell-hide">
#     <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#     </div>
#    </td>
#    <td class="twc-sticky-col" classname="twc-sticky-col" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="day" title="Scattered thunderstorms in the morning, then mainly cloudy during the afternoon with thunderstorms likely. High around 85F. Winds N at 5 to 10 mph. Chance of rain 80%.">
#     <div>
#      <div>
#       <span class="date-time">
#        Sat
#       </span>
#       <icon class="icon icon-svg icon-svg-dark icon-thunderstorm icon-4" classname="icon icon-svg icon-svg-dark icon-thunderstorm icon-4">
#        <svg class="svg-thunderstorm" viewbox="0 0 200 200" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <use class="svg-cloud" transform="translate(0 -41)" xlink:href="#svg-symbol-cloud">
#         </use>
#         <use class="svg-lightning" xlink:href="#svg-symbol-lightning-bolt">
#         </use>
#         <use class="svg-drop" transform="translate(72)" xlink:href="#svg-symbol-drop">
#         </use>
#         <use class="svg-drop" transform="matrix(1.7 0 0 2 -16 -113)" xlink:href="#svg-symbol-drop">
#         </use>
#        </svg>
#       </icon>
#       <div class="twc-table-shadow sticky" classname="twc-table-shadow sticky">
#       </div>
#      </div>
#      <span class="day-detail clearfix">
#       MAR 9
#      </span>
#     </div>
#    </td>
#    <td class="description" classname="description" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="description" title="Scattered thunderstorms in the morning, then mainly cloudy during the afternoon with thunderstorms likely. High around 85F. Winds N at 5 to 10 mph. Chance of rain 80%.">
#     <span>
#      Thunderstorms
#     </span>
#    </td>
#    <td class="temp" classname="temp" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="hi-lo" title="Scattered thunderstorms in the morning, then mainly cloudy during the afternoon with thunderstorms likely. High around 85F. Winds N at 5 to 10 mph. Chance of rain 80%.">
#     <div>
#      <span class="">
#       85
#       <sup>
#        °
#       </sup>
#      </span>
#      <span class="slash" classname="slash">
#      </span>
#      <span class="">
#       69
#       <sup>
#        °
#       </sup>
#      </span>
#     </div>
#    </td>
#    <td class="precip" classname="precip" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="precip" title="Scattered thunderstorms in the morning, then mainly cloudy during the afternoon with thunderstorms likely. High around 85F. Winds N at 5 to 10 mph. Chance of rain 80%.">
#     <div>
#      <span class="icon icon-font iconset-weather-data icon-drop-1" classname="icon icon-font iconset-weather-data icon-drop-1">
#      </span>
#      <span class="">
#       <span>
#        80
#        <span class="Percentage__percentSymbol__2Q_AR">
#         %
#        </span>
#       </span>
#      </span>
#     </div>
#    </td>
#    <td class="wind" classname="wind" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="wind" title="Scattered thunderstorms in the morning, then mainly cloudy during the afternoon with thunderstorms likely. High around 85F. Winds N at 5 to 10 mph. Chance of rain 80%.">
#     <span class="">
#      N 6 mph
#     </span>
#    </td>
#    <td class="humidity" classname="humidity" data-track-string="ls_24_hour_ls_24_hour_toggle" headers="humidity" title="Scattered thunderstorms in the morning, then mainly cloudy during the afternoon with thunderstorms likely. High around 85F. Winds N at 5 to 10 mph. Chance of rain 80%.">
#     <span class="">
#      <span>
#       68
#       <span class="Percentage__percentSymbol__2Q_AR">
#        %
#       </span>
#      </span>
#     </span>
#    </td>
#   </tr>
#  </tbody>
# </table>

# %%
table_body = table.find('tbody')

# %%
rows = table_body.find_all('tr')
for row in rows:
    cols = row.find_all('td')
    cols = [ele.text.strip() for ele in cols]
    data.append([ele for ele in cols if ele])

# %%
print(data)
# Out:
# [['Today\nFEB 23', 'Scattered Thunderstorms', '87°69°', '60%', 'NW 9 mph', '61%'], ['SunFEB 24', 'Thunderstorms', '90°70°', '80%', 'NNW 10 mph', '61%'], ['MonFEB 25', 'Thunderstorms', '86°69°', '80%', 'NW 10 mph', '67%'], ['TueFEB 26', 'Thunderstorms', '82°69°', '100%', 'NW 8 mph', '75%'], ['WedFEB 27', 'Thunderstorms', '79°68°', '90%', 'NW 7 mph', '79%'], ['ThuFEB 28', 'Thunderstorms', '78°67°', '90%', 'N 6 mph', '82%'], ['FriMAR 1', 'Thunderstorms', '79°67°', '80%', 'E 6 mph', '80%'], ['SatMAR 2', 'Thunderstorms', '79°67°', '80%', 'ENE 6 mph', '79%'], ['SunMAR 3', 'Thunderstorms', '81°67°', '80%', 'ENE 6 mph', '76%'], ['MonMAR 4', 'Thunderstorms', '81°67°', '80%', 'ENE 6 mph', '74%'], ['TueMAR 5', 'Thunderstorms', '83°68°', '80%', 'NNE 7 mph', '72%'], ['WedMAR 6', 'Thunderstorms', '83°68°', '80%', 'N 6 mph', '70%'], ['Thu\nMAR 7', 'Scattered Thunderstorms', '84°68°', '60%', 'NNE 6 mph', '69%'], ['Fri\nMAR 8', 'Scattered Thunderstorms', '84°68°', '60%', 'NE 6 mph', '69%'], ['SatMAR 9', 'Thunderstorms', '85°69°', '80%', 'N 6 mph', '68%']]
